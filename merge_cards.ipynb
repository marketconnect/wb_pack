# %%
import pandas as pd
import json
import getpass
import requests
import datetime
import os
import math
import re
import time

# %%
WB_TOKEN = os.getenv('WB_TOKEN')
headers = {'Authorization': WB_TOKEN}

# %%
def get_cards_list(api_key, updated_at=None, nm_id=None, limit=100):
    headers = {
        "Authorization": api_key,
        "Content-Type": "application/json"
    }
    
    cards_list_url = "https://content-api.wildberries.ru/content/v2/get/cards/list"
    
    # Базовый запрос
    body = {
        "settings": {
            "cursor": {
                "limit": limit
            },
            "filter": {
                "withPhoto": 1,
                "objectIDs": [3979]
            }
        }
    }
    
    # Добавляем параметры, если они переданы
    if updated_at:
        body["settings"]["cursor"]["updatedAt"] = updated_at
    if nm_id:
        body["settings"]["cursor"]["nmID"] = nm_id
    
    try:
        response = requests.post(cards_list_url, headers=headers, json=body)
        response.raise_for_status()  # Выбросит исключение, если статус ответа не 200
        return response.json()
    except requests.RequestException as e:
        print(f"Ошибка при запросе списка карточек: {e}")
        return None

# %%
vendor_code_pattern = re.compile(r"^box_\d+_\d+$")
all_cards = []
updated_at = None
nm_id = None

while True:
    response = get_cards_list(WB_TOKEN, updated_at=updated_at, nm_id=nm_id)

    if not response or "cards" not in response:
        print("Запрос завершён или нет данных.")
        break

    cards = response["cards"]
    if not cards:
        print("Больше нет карточек.")
        break
    
    filtered_cards = [card for card in cards if "vendorCode" in card and vendor_code_pattern.match(card["vendorCode"])]
    all_cards.extend(filtered_cards)

    # Обновляем параметры для следующего запроса
    cursor = response.get("cursor", {})
    updated_at = cursor.get("updatedAt")
    nm_id = cursor.get("nmID")

    # Если нет курсора, значит, это последняя страница
    if not updated_at or not nm_id:
        break

    print(f"Загружено {len(all_cards)} карточек, продолжаем...")
# Out:
# Загружено 100 карточек, продолжаем...
# Загружено 200 карточек, продолжаем...
# Загружено 270 карточек, продолжаем...
# Больше нет карточек.

# %%
all_cards
# Out:
# [{'nmID': 323158312,
#   'imtID': 304586570,
#   'nmUUID': '0194bc4c-a303-7b88-96d4-5ecda5a6a204',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9603052_10',
#   'brand': '',
#   'title': 'Коробка крафт кондитерская, беленая, 215*150*60 мм 10 шт.',
#   'description': 'Коробка крафт кондитерская, беленая, длиной 215 мм, шириной 150 мм и высотой 60 мм. Изготовлена из крафт картона. Полезный объём — 1.94 л.\nОбласть применения:\nПредназначена для упаковки и транспортировки кондитерских изделий — пирожных, чизкейков, печенья, кексов, вафель. Изготовлена из картона светлого оттенка, который придаёт коробке аккуратный вид. Закрывается при помощи крышки — удлиннённой боковой стенки.\nПреимущества:\nЗакрывается крышкой-стенкой\nВозможность маркировки картонной поверхности.\nЗащищает продукты от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из крафт картона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ℃ и относительной влажности (65∓15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения изделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158312/images/tm/1.webp'}],
#   'dimensions': {'width': 80, 'height': 3, 'length': 60, 'isValid': True},
#   'characteristics': [{'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 350},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 6},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 21.5}],
#   'sizes': [{'chrtID': 485924589,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760413']}],
#   'createdAt': '2025-01-31T12:18:49.320288Z',
#   'updatedAt': '2025-01-31T12:31:53.354906Z'},
#  {'nmID': 323158349,
#   'imtID': 304586606,
#   'nmUUID': '0194bc4c-a93b-75c8-9718-8152fde0750e',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604716_50',
#   'brand': '',
#   'title': 'Короб №206 (премиум), бордовый, 180*110*85 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №206 (премиум), бордовый, длиной 180 мм, шириной 110 мм и высотой 85 мм. Изготовлен из микрогофрокартона Е-22. Полезный объём — 1.68 л.\nОбласть применения:\nЭтот короб станет отличным вариантом для упаковки подарка. В него поместятся милые сердцу безделушки, сладости, сувениры и даже коробочка с кольцом или браслетом. В качестве украшения коробки можно выбрать одну из ярких атласных лент. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158349/images/tm/1.webp'}],
#   'dimensions': {'width': 63, 'height': 15, 'length': 58, 'isValid': True},
#   'characteristics': [{'id': 90652, 'name': 'Глубина предмета', 'value': 18},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Е-22']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 11},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Прямоугольная']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 8.5},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 2300}],
#   'sizes': [{'chrtID': 485924628,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760932']}],
#   'createdAt': '2025-01-31T12:18:51.030021Z',
#   'updatedAt': '2025-01-31T12:31:52.16293Z'},
#  {'nmID': 323158299,
#   'imtID': 304586556,
#   'nmUUID': '0194bc4c-a5f9-7f10-96fd-5668accccdae',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604404_10',
#   'brand': '',
#   'title': 'Коробка №199 (премиум), 110*100*70 мм 10 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №199 (премиум) бурого цвета, длиной 110 мм, шириной 100 мм и высотой 70 мм. Изготовлен из микрогофрокартона Е-22. Полезный объём — 0.77 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших и лёгких предметов — сыпучих продуктов в заводской упаковке (приправы, кофе, чай), косметики, украшений и сувениров. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой с прорезью, в которую при закрытии вставляется дополнительный клапан-замок, расположенный на боковой стороне.\nПреимущества:\nплотно прилегающая крышка с прорезью для клапана-замка;\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nкомпактный размер коробки;\nнизкая стоимость;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158299/images/tm/1.webp'}],
#   'dimensions': {'width': 46, 'height': 3, 'length': 39, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 10},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 380},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Е-22']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Прямоугольная']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 11},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 7}],
#   'sizes': [{'chrtID': 485924576,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760284']}],
#   'createdAt': '2025-01-31T12:18:48.639341Z',
#   'updatedAt': '2025-01-31T12:31:51.653609Z'},
#  {'nmID': 323158308,
#   'imtID': 304586566,
#   'nmUUID': '0194bc4c-a38b-7a6f-96de-fe3386c08453',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9603052_30',
#   'brand': '',
#   'title': 'Коробка крафт кондитерская, беленая, 215*150*60 мм 30 шт.',
#   'description': 'Коробка крафт кондитерская, беленая, длиной 215 мм, шириной 150 мм и высотой 60 мм. Изготовлена из крафт картона. Полезный объём — 1.94 л.\nОбласть применения:\nПредназначена для упаковки и транспортировки кондитерских изделий — пирожных, чизкейков, печенья, кексов, вафель. Изготовлена из картона светлого оттенка, который придаёт коробке аккуратный вид. Закрывается при помощи крышки — удлиннённой боковой стенки.\nПреимущества:\nЗакрывается крышкой-стенкой\nВозможность маркировки картонной поверхности.\nЗащищает продукты от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из крафт картона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ℃ и относительной влажности (65∓15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения изделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158308/images/tm/1.webp'}],
#   'dimensions': {'width': 80, 'height': 9, 'length': 60, 'isValid': True},
#   'characteristics': [{'id': 90630, 'name': 'Высота предмета', 'value': 6},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 1050},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 21.5},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['30']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 15}],
#   'sizes': [{'chrtID': 485924585,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760383']}],
#   'createdAt': '2025-01-31T12:18:49.200724Z',
#   'updatedAt': '2025-01-31T12:31:50.885532Z'},
#  {'nmID': 323158265,
#   'imtID': 304586517,
#   'nmUUID': '0194bc4c-9797-769d-967d-5b5380387280',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604580_50',
#   'brand': '',
#   'title': 'Коробка №204/1 (премиум), беленая, 135*85*55 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №204/1 (премиум) белёный, длиной 135 мм, шириной 85 мми высотой 55 мм. Изготовлен из микрогофрокартона Е-22. Полезный объём — 0.6 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nкомпактные размеры коробки;\nнизкая стоимость.\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158265/images/tm/1.webp'}],
#   'dimensions': {'width': 48, 'height': 15, 'length': 41, 'isValid': True},
#   'characteristics': [{'id': 179792,
#     'name': 'Количество предметов в упаковке',
#     'value': ['50']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 8.5},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 1300},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 5.5},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 13.5},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Е-22']}],
#   'sizes': [{'chrtID': 485924537,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698759905']}],
#   'createdAt': '2025-01-31T12:18:43.883179Z',
#   'updatedAt': '2025-01-31T12:31:50.885532Z'},
#  {'nmID': 323158305,
#   'imtID': 304586563,
#   'nmUUID': '0194bc4c-a081-7cb4-96bd-18c0c87793a2',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602803_50',
#   'brand': '',
#   'title': 'Короб КС-410 МГФ, белый, 130*130*70 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-410 МГФ, серии КС-400, белый, длиной 130 мм, шириной 130 мм и высотой 70 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.15 л.\nОбласть применения:\nЭтот короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. Сюда поместятся сувениры и украшения, косметика и лекарства, пуговицы и бусины, товары хэнд-мэйд или даже сладости. Оберните коробку в одну из ярких атласных лент, чтобы придать ей вид подарочной упаковки. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158305/images/tm/1.webp'}],
#   'dimensions': {'width': 57, 'height': 15, 'length': 44, 'isValid': True},
#   'characteristics': [{'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 2100},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 13},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 13},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 7},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']}],
#   'sizes': [{'chrtID': 485924582,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760352']}],
#   'createdAt': '2025-01-31T12:18:49.093307Z',
#   'updatedAt': '2025-01-31T12:31:50.675411Z'},
#  {'nmID': 323158354,
#   'imtID': 304586613,
#   'nmUUID': '0194bc4c-b485-72f2-978e-953fcfb6080a',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_222200_50',
#   'brand': '',
#   'title': 'Короб КС-21, 200*120*30 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-21 бурый, длиной 200 мм, шириной 120 мм и высотой 30 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 0.72 л.\nОбласть применения:\nЭтот небольшой короб удобен для хранения и транспортировки ценных мелочей, которые легко потерять во время транспортировки. Сюда поместятся канцтовары (ручки, линейки, карандаши), украшения, сувениры, бытовые мелочи и сладости. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nплотно прилегающая крышка;\nупаковка без помощи клея и скотча;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158354/images/tm/1.webp'}],
#   'dimensions': {'width': 70, 'height': 15, 'length': 50, 'isValid': True},
#   'characteristics': [{'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 12},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 20},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 3},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-24 В']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 2300}],
#   'sizes': [{'chrtID': 485924633,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760994']}],
#   'createdAt': '2025-01-31T12:18:51.408165Z',
#   'updatedAt': '2025-01-31T12:31:50.158031Z'},
#  {'nmID': 323158332,
#   'imtID': 304586590,
#   'nmUUID': '0194bc4c-b03e-7104-975b-c823d25c3fb8',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602815_50',
#   'brand': '',
#   'title': 'Короб КС-421 МГФ, белый, 150*150*55 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-421 МГФ, серии КС-400, белый, длиной 150 мм, шириной 150 мм и высотой 55 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.2 л.\nОбласть применения:\nЭтот небольшой плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. У него есть откидная крышка, которая плотно закрывается, поэтому мелкие предметы не выпадут во время перевозки. Вы можете положить в короб небольшие сувениры и украшения в подарок близкому человеку, набор магнитов с холодильника на время переезда, коллекцию редких монет и многое другое. Чтобы украсить коробку изнутри и не повредить предметы в период транспортировки, положите внутрь цветнойподарочный наполнитель. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158332/images/tm/1.webp'}],
#   'dimensions': {'width': 66, 'height': 15, 'length': 45, 'isValid': True},
#   'characteristics': [{'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 5.5},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 3000},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 15},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']}],
#   'sizes': [{'chrtID': 485924609,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760758']}],
#   'createdAt': '2025-01-31T12:18:50.112725Z',
#   'updatedAt': '2025-01-31T12:31:49.245144Z'},
#  {'nmID': 323158319,
#   'imtID': 304586577,
#   'nmUUID': '0194bc4c-a001-7dfd-96bd-9940677a6e25',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604317_30',
#   'brand': '',
#   'title': 'Коробка №200/1 (премиум), беленая, 210*150*90 мм 30 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №200/1 (премиум) белёный, длиной 210 мм, шириной 150 мм и высотой 90 мм. Изготовлениз микрогофрокартона Е-22. Полезный объём — 2.83 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158319/images/tm/1.webp'}],
#   'dimensions': {'width': 79, 'height': 9, 'length': 66, 'isValid': True},
#   'characteristics': [{'id': 90652, 'name': 'Глубина предмета', 'value': 21},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Е-22']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['30']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 9},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 2040},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']}],
#   'sizes': [{'chrtID': 485924596,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760505']}],
#   'createdAt': '2025-01-31T12:18:49.491134Z',
#   'updatedAt': '2025-01-31T12:31:48.701498Z'},
#  {'nmID': 323158303,
#   'imtID': 304586562,
#   'nmUUID': '0194bc4c-a662-7646-9708-8c58fce81a63',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602808_10',
#   'brand': '',
#   'title': 'Короб КС-415 МГФ, белый, 170*75*35 мм 10 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-415 МГФ, серии КС-400, белый, длиной 170 мм, шириной 75 мм и высотой 35 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.4 л.\nОбласть применения:\nЭтот миниатюрный плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. Кольцо для любимой девушки, изящный браслет для подруги, стразы и бусины, мелкие крепёжные изделия, школьные валентинки и записки или коллекция редких монет — можно придумать сотни вариантов для его использования. Добавьте в коробку подарочный наполнитель, чтобы сюрприз попал к адресату целым и невредимым или удачно перенёс долгий переезд. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158303/images/tm/1.webp'}],
#   'dimensions': {'width': 53, 'height': 3, 'length': 45, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 7.5},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 3.5},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 17},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 200},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23']}],
#   'sizes': [{'chrtID': 485924580,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760345']}],
#   'createdAt': '2025-01-31T12:18:48.810857Z',
#   'updatedAt': '2025-01-31T12:31:47.985774Z'},
#  {'nmID': 323158274,
#   'imtID': 304586526,
#   'nmUUID': '0194bc4c-9abf-7e4a-9694-884b8a908673',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602808_30',
#   'brand': '',
#   'title': 'Короб КС-415 МГФ, белый, 170*75*35 мм 30 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-415 МГФ, серии КС-400, белый, длиной 170 мм, шириной 75 мм и высотой 35 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.4 л.\nОбласть применения:\nЭтот миниатюрный плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. Кольцо для любимой девушки, изящный браслет для подруги, стразы и бусины, мелкие крепёжные изделия, школьные валентинки и записки или коллекция редких монет — можно придумать сотни вариантов для его использования. Добавьте в коробку подарочный наполнитель, чтобы сюрприз попал к адресату целым и невредимым или удачно перенёс долгий переезд. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158274/images/tm/1.webp'}],
#   'dimensions': {'width': 53, 'height': 9, 'length': 45, 'isValid': True},
#   'characteristics': [{'id': 90630, 'name': 'Высота предмета', 'value': 3.5},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 17},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['30']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 7.5},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 600},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']}],
#   'sizes': [{'chrtID': 485924546,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760024']}],
#   'createdAt': '2025-01-31T12:18:44.870381Z',
#   'updatedAt': '2025-01-31T12:31:34.678482Z'},
#  {'nmID': 323158271,
#   'imtID': 304586524,
#   'nmUUID': '0194bc4c-9a0b-7c13-968d-82b043a4ea27',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602822_10',
#   'brand': '',
#   'title': 'Короб КС-428 МГФ, белый, 210*75*40 мм 10 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-428 МГФ, серии КС-400, белый, длиной 210 мм, шириной 75 мм и высотой 40 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.6 л.\nОбласть применения:\nПродолговатый плоский короб подойдёт для упаковки и транспортировки ювелирных украшений и бижутерии, сладостей или канцелярских товаров — линеек, карандашей и ручек, канцелярских ножей и ножниц. Если вы планируете использовать эту коробку в качестве подарочной упаковки, рекомендуем добавить в коробкубумажный наполнитель, чтобы предметы не повредились во время перевозки. Украсить внешний вид коробки можно с помощью бумаги тишью, обёрточной бумаги и других ярких товаров для оформления и декора.Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158271/images/tm/1.webp'}],
#   'dimensions': {'width': 62, 'height': 3, 'length': 55, 'isValid': True},
#   'characteristics': [{'id': 15002205,
#     'name': 'Марка картона',
#     'value': ['Т-23']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 4},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 7.5},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 21},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 310},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']}],
#   'sizes': [{'chrtID': 485924543,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698759981']}],
#   'createdAt': '2025-01-31T12:18:44.578146Z',
#   'updatedAt': '2025-01-31T12:31:31.219839Z'},
#  {'nmID': 323158297,
#   'imtID': 304586554,
#   'nmUUID': '0194bc4c-a47f-7270-96eb-53a4e54bf9f7',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9602798_50',
#   'brand': '',
#   'title': 'Короб КС-405 МГФ, белый, 195*135*75 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-405 МГФ, серии КС-400, белый, длиной 195 мм, шириной 135 мм и высотой 75 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.95 л.\nОбласть применения:\nЭтот короб станет отличным вариантом для упаковки подарка. В него поместятся милые сердцу безделушки, сладости, сувениры и даже коробочка с кольцом или браслетом. В качестве украшения коробки можно выбрать одну из ярких атласных лент. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из микрогофрокартона Т-23;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158297/images/tm/1.webp'}],
#   'dimensions': {'width': 72, 'height': 15, 'length': 59, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 13.5},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 19.5},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 3000},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 7.5},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23']}],
#   'sizes': [{'chrtID': 485924574,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760260']}],
#   'createdAt': '2025-01-31T12:18:48.468717Z',
#   'updatedAt': '2025-01-31T12:31:31.123481Z'},
#  {'nmID': 323158295,
#   'imtID': 304586552,
#   'nmUUID': '0194bc4c-9d0a-7235-96a2-b56d43dc2067',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_222212_50',
#   'brand': '',
#   'title': 'Короб КС-55, 380*175*55 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-55 бурый, длиной 380 мм, шириной 175 мм и высотой 55 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 3.66 л.\nОбласть применения:\nПродолговатый короб удобен для хранения и транспортировки узких и длинных вещей. Сюда поместятся канцтовары (ручки, линейки, карандаши), украшения, сувениры, бытовые мелочи и сладости. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nплотно прилегающая крышка;\nупаковка без помощи клея и скотча;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158295/images/tm/1.webp'}],
#   'dimensions': {'width': 122, 'height': 15, 'length': 95, 'isValid': False},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 17.5},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 38},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 4950},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 5.5},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-24 В']}],
#   'sizes': [{'chrtID': 485924572,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760246']}],
#   'createdAt': '2025-01-31T12:18:48.329663Z',
#   'updatedAt': '2025-01-31T12:31:31.123481Z'},
#  {'nmID': 323158298,
#   'imtID': 304586555,
#   'nmUUID': '0194bc4c-9e94-7e0a-96ae-21f0a4828c7a',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_222122_10',
#   'brand': '',
#   'title': 'Короб КС-27, 130*80*55 мм 10 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-27 бурый, длиной 130 мм, шириной 80 мм и высотой 55 мм. Изготовлен из трёхслойного картона Т-23 В. Полезный объём — 0.57 л.\nОбласть применения:\nКороб с прилегающей крышкой удобен для хранения и транспортировки ценных вещей и мелочей, которые легко потерять. Сюда поместятся украшения и небольшие сувениры, ручки и карандаши, косметика, ключи, зарядные устройства, батарейки, медикаменты или щётки с зубной пастой. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323158/323158298/images/tm/1.webp'}],
#   'dimensions': {'width': 46, 'height': 3, 'length': 40, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 8},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 13},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 5.5},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23 В']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 410},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']}],
#   'sizes': [{'chrtID': 485924575,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698760277']}],
#   'createdAt': '2025-01-31T12:18:48.579879Z',
#   'updatedAt': '2025-01-31T12:31:30.576625Z'},
#  {'nmID': 323158266,
#   'imtID': 304586519,
#   'nmUUID': '0194bc4c-981a-7980-9688-8eea941cd972',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9601645_30',
#   'brand': '',
#   'title': 'Картонная коробка для бутылки №95, 100*100*310 мм 30 шт.',
# ...
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162014/images/tm/1.webp'}],
#   'dimensions': {'width': 95, 'height': 3, 'length': 70, 'isValid': True},
#   'characteristics': [{'id': 14177451,
#     'name': 'Страна производства',
#     'value': ['Россия']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 27},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23 В']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 5},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 16.5},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 790},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']}],
#   'sizes': [{'chrtID': 485929696,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698806593']}],
#   'createdAt': '2025-01-31T12:26:15.799859Z',
#   'updatedAt': '2025-01-31T12:27:06.003975Z'},
#  {'nmID': 323162002,
#   'imtID': 304589726,
#   'nmUUID': '0194bc4d-46f6-721e-a208-48e128032d5b',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9603334_50',
#   'brand': '',
#   'title': 'Короб 200*150*200 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКартонный короб Деловые Линии тип «D1» бурого цвета, длиной 200 мм, шириной 150 мм и высотой 200 мм. Изготовлен из трехслойного картона марки Т-23 В. Полезный объём — 6 л.\nОбласть применения:\nПредназначен для отправки грузов транспортной компанией Деловые Линии. Изготовлен из целлюлозы, поэтому отличается износостойкостью и пригоден для последующего использования. Картонный короб Деловые Линии тип «D1» подходит для отправки посылок средних размеров: предметов одежды и обуви, детских игрушек, набора елочных украшений. Если вы приобретаете больше одной коробки, рекомендуем маркировать их с помощью стикеров или маркеров, чтобы не забыть, какие товары находятся в каждой из них.\nПреимущества:\nЛегко упаковывается с помощью скотча.\nВозможность маркировки картонной поверхности.\nЗащищает вещи от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162002/images/tm/1.webp'}],
#   'dimensions': {'width': 77, 'height': 15, 'length': 88, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 20},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 20},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Прямоугольная']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 4100},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23 В']}],
#   'sizes': [{'chrtID': 485929679,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698806364']}],
#   'createdAt': '2025-01-31T12:26:15.09415Z',
#   'updatedAt': '2025-01-31T12:27:06.003975Z'},
#  {'nmID': 323162000,
#   'imtID': 304589724,
#   'nmUUID': '0194bc4d-08e8-7407-8bf4-78edf4b7479a',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604614_50',
#   'brand': '',
#   'title': 'Короб 180*90*20 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКоробка под чехол для телефона бурого цвета, длиной 180 мм, шириной 90 мм и высотой 20 мм.\nКоробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея искотча. Снабжена откидной крышкой.\nОбласть применения:\nПредназначена для упаковки, транспортировки и хранения смартфонов и аксессуаров для них — чехлов и защитных стёкол. Если вам необходимо убрать чехол или защитное стекло на длительное хранение, такая коробка убережёттовар от воздействия солнечных лучей и, как следствие, выцветания.\nМожно использовать для хранения и транспортировки любых других предметов, подходящих по габаритам — обложек для паспорта, блокнотов, украшений и сувениров.\nПреимущества:\nплотно прилегающая крышка;\nпрямоугольная форма, удобная для упаковки смартфона;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из прочного микрогофрокартона марки Т-24 Е;\nнебольшой вес (актуально при отправлении посылки);\nэкологичность.\nЧтобы коробка выглядела ярче, рекомендуем обернуть её в яркую подарочную бумагу и перевязать атласной лентой. А благодаря бумажному наполнителю или воздушно-пузырьковой плёнке вы можете не беспокоиться за сохранность товара.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162000/images/tm/1.webp'}],
#   'dimensions': {'width': 59, 'height': 15, 'length': 44, 'isValid': True},
#   'characteristics': [{'id': 88952,
#     'name': 'Вес товара с упаковкой (г)',
#     'value': 1050},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 90673, 'name': 'Ширина предмета', 'value': 9},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-24 Е']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 18},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 2}],
#   'sizes': [{'chrtID': 485929677,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698806340']}],
#   'createdAt': '2025-01-31T12:26:14.94788Z',
#   'updatedAt': '2025-01-31T12:27:06.003975Z'},
#  {'nmID': 323162020,
#   'imtID': 304589743,
#   'nmUUID': '0194bc4d-0222-7fbe-8bbb-ac9e8ebdf7bf',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9603334_10',
#   'brand': '',
#   'title': 'Короб 200*150*200 мм 10 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКартонный короб Деловые Линии тип «D1» бурого цвета, длиной 200 мм, шириной 150 мм и высотой 200 мм. Изготовлен из трехслойного картона марки Т-23 В. Полезный объём — 6 л.\nОбласть применения:\nПредназначен для отправки грузов транспортной компанией Деловые Линии. Изготовлен из целлюлозы, поэтому отличается износостойкостью и пригоден для последующего использования. Картонный короб Деловые Линии тип «D1» подходит для отправки посылок средних размеров: предметов одежды и обуви, детских игрушек, набора елочных украшений. Если вы приобретаете больше одной коробки, рекомендуем маркировать их с помощью стикеров или маркеров, чтобы не забыть, какие товары находятся в каждой из них.\nПреимущества:\nЛегко упаковывается с помощью скотча.\nВозможность маркировки картонной поверхности.\nЗащищает вещи от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162020/images/tm/1.webp'}],
#   'dimensions': {'width': 77, 'height': 3, 'length': 88, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Прямоугольная']},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 20},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Т-23 В']},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 820},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 20},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['10']},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']}],
#   'sizes': [{'chrtID': 485929705,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698806708']}],
#   'createdAt': '2025-01-31T12:26:16.260402Z',
#   'updatedAt': '2025-01-31T12:27:04.965326Z'},
#  {'nmID': 323162016,
#   'imtID': 304589740,
#   'nmUUID': '0194bc4c-f0a2-7d62-8b0b-44bf75054134',
#   'subjectID': 3979,
#   'subjectName': 'Коробки картонные',
#   'vendorCode': 'box_9604623_50',
#   'brand': '',
#   'title': 'Короб «С Новым годом!» 210*150*90 мм 50 шт.',
#   'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nПодарочная коробка «С Новым годом!» чёрная, с поздравительной надписью, длиной 210 мм, шириной 150 мм и высотой 90 мм. Изготовлена из микрогофрокартона Е-22. Полезный объём — 2.83 л.\nОбласть применения:\nПорадуйте своих близких не только приятным сувениром, но и его упаковкой! Эта коробка— идеальный вариант для тех, кто не умеет красиво упаковывать подарки своими руками или просто не успевает это сделать.\nВам не придётся заучивать поздравительную речь, ведь на лицевой и внутренней сторонах коробки написаны новогодние поздравления, поэтому она всё скажет за вас.\nОна достаточно вместительная, чтобы положить туда коробку с новым айфоном, статуэтку Деда Мороза или долгожданные духи в изысканном флаконе.\nСама коробка имеет насыщенный чёрный цвет, новы можете добавить ей яркости и декорироватьатласной лентой, а сам сюрприз упаковать вподарочный наполнитель.\nПреимущества:\nплотно прилегающая крышка;\nнадпись на коробке с поздравлением;\nкомпактный размер и яркий цвет коробки;\nне требуется дополнительная упаковка скотчем;\nнизкая стоимость;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.',
#   'needKiz': False,
#   'photos': [{'big': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/big/1.webp',
#     'c246x328': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/c246x328/1.webp',
#     'c516x688': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/c516x688/1.webp',
#     'hq': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/hq/1.webp',
#     'square': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/square/1.webp',
#     'tm': 'https://basket-19.wbbasket.ru/vol3231/part323162/323162016/images/tm/1.webp'}],
#   'dimensions': {'width': 79, 'height': 15, 'length': 66, 'isValid': True},
#   'characteristics': [{'id': 90673, 'name': 'Ширина предмета', 'value': 15},
#    {'id': 14177449, 'name': 'Цвет', 'value': ['крафт']},
#    {'id': 88952, 'name': 'Вес товара с упаковкой (г)', 'value': 3400},
#    {'id': 90652, 'name': 'Глубина предмета', 'value': 21},
#    {'id': 15002205, 'name': 'Марка картона', 'value': ['Е-22']},
#    {'id': 179792, 'name': 'Количество предметов в упаковке', 'value': ['50']},
#    {'id': 90630, 'name': 'Высота предмета', 'value': 9},
#    {'id': 14177451, 'name': 'Страна производства', 'value': ['Россия']},
#    {'id': 15000432, 'name': 'Форма коробки', 'value': ['Плоская']}],
#   'sizes': [{'chrtID': 485929698,
#     'techSize': '0',
#     'wbSize': '',
#     'skus': ['2042698806647']}],
#   'createdAt': '2025-01-31T12:26:16.010749Z',
#   'updatedAt': '2025-01-31T12:27:04.347123Z'}]

# %%
vendor_code_pattern = re.compile(r"^box_(\d+)_(\d+)$")  # Корректируем регулярку
filtered_cards = []
for card in all_cards:
    match = vendor_code_pattern.match(card['vendorCode'])
    if match:
        filtered_cards.append(card)

# Группируем карточки по числовому префиксу из vendorCode (box_XXXXXXX)
grouped_by_prefix = {}
for card in filtered_cards:
    match = vendor_code_pattern.match(card['vendorCode'])
    if match:
        prefix = match.group(1)  # Извлекаем число XXXX из box_XXXX_YY
        if prefix not in grouped_by_prefix:
            grouped_by_prefix[prefix] = []
        grouped_by_prefix[prefix].append(card)

# %%
final_groups = []
for prefix, cards in grouped_by_prefix.items():
    sorted_cards = sorted(cards, key=lambda x: x['nmID'])  # Сортируем по nmID
    for i in range(0, len(sorted_cards), 3):  # Берем по 3 карточки за раз
        batch = sorted_cards[i:i+3]
        if len(batch) > 1:  # Только если в группе больше 1 карточки
            final_groups.append(batch)

# %%
WB_API_URL = "https://content-api.wildberries.ru/content/v2/cards/moveNm"
for group in final_groups:
    imt_id = group[0]['imtID']  # Первый элемент как targetIMT
    nm_ids = [card['nmID'] for card in group]  # nmID карточек для объединения

    payload = {
        "targetIMT": imt_id,
        "nmIDs": nm_ids
    }
    
    response = requests.post(WB_API_URL, json=payload, headers=headers)
    time.sleep(1)
    if response.status_code == 200:
        print(f"✅ Успешно объединены карточки {nm_ids} под imtID {imt_id}")
    else:
        print(f"❌ Ошибка при объединении {nm_ids}: {response.text}")
# Out:
# ✅ Успешно объединены карточки [323158308, 323158312, 323158431] под imtID 304586566
# ✅ Успешно объединены карточки [323158349, 323158484, 323158651] под imtID 304586606
# ✅ Успешно объединены карточки [323158299, 323158507, 323158712] под imtID 304586556
# ✅ Успешно объединены карточки [323158265, 323158382, 323158753] под imtID 304586517
# ✅ Успешно объединены карточки [323158305, 323158476, 323158604] под imtID 304586563
# ✅ Успешно объединены карточки [323158310, 323158354, 323158684] под imtID 304586568
# ✅ Успешно объединены карточки [323158332, 323158504, 323158562] под imtID 304586590
# ✅ Успешно объединены карточки [323158319, 323158379, 323158766] под imtID 304586577
# ✅ Успешно объединены карточки [323158274, 323158303, 323158719] под imtID 304586526
# ✅ Успешно объединены карточки [323158271, 323158699, 323158760] под imtID 304586524
# ✅ Успешно объединены карточки [323158297, 323158301, 323158512] под imtID 304586554
# ✅ Успешно объединены карточки [323158295, 323158461, 323158528] под imtID 304586552
# ✅ Успешно объединены карточки [323158298, 323158534, 323158744] под imtID 304586555
# ✅ Успешно объединены карточки [323158266, 323158645, 323158662] под imtID 304586519
# ✅ Успешно объединены карточки [323158272, 323158314, 323158329] под imtID 304586525
# ✅ Успешно объединены карточки [323158270, 323158321, 323158508] под imtID 304586523
# ✅ Успешно объединены карточки [323158294, 323158480, 323158640] под imtID 304586551
# ✅ Успешно объединены карточки [323158296, 323158485, 323158726] под imtID 304586553
# ✅ Успешно объединены карточки [323158300, 323158605, 323158716] под imtID 304586557
# ✅ Успешно объединены карточки [323158269, 323158320, 323158482] под imtID 304586522
# ✅ Успешно объединены карточки [323158306, 323158560, 323158748] под imtID 304586564
# ✅ Успешно объединены карточки [323158309, 323158674, 323158696] под imtID 304586567
# ✅ Успешно объединены карточки [323158302, 323158502, 323158759] под imtID 304586559
# ✅ Успешно объединены карточки [323158316, 323158326, 323158469] под imtID 304586574
# ✅ Успешно объединены карточки [323158304, 323158373, 323158618] под imtID 304586561
# ✅ Успешно объединены карточки [323158313, 323158667, 323158767] под imtID 304586571
# ✅ Успешно объединены карточки [323158311, 323158488, 323158724] под imtID 304586569
# ✅ Успешно объединены карточки [323158351, 323158456, 323160316] под imtID 304586609
# ✅ Успешно объединены карточки [323158345, 323158378, 323158749] под imtID 304586602
# ✅ Успешно объединены карточки [323158323, 323158376, 323158465] под imtID 304586582
# ✅ Успешно объединены карточки [323158427, 323158597, 323158706] под imtID 304586682
# ✅ Успешно объединены карточки [323158369, 323158481, 323158601] под imtID 304586623
# ✅ Успешно объединены карточки [323158325, 323158517, 323158701] под imtID 304586584
# ✅ Успешно объединены карточки [323158344, 323158425, 323158454] под imtID 304586601
# ✅ Успешно объединены карточки [323158377, 323158493, 323158756] под imtID 304586631
# ✅ Успешно объединены карточки [323158451, 323158666, 323158679] под imtID 304586708
# ✅ Успешно объединены карточки [323158338, 323158510, 323158521] под imtID 304586595
# ✅ Успешно объединены карточки [323158462, 323158467, 323158720] под imtID 304586831
# ✅ Успешно объединены карточки [323158363, 323158455, 323158474] под imtID 304586618
# ✅ Успешно объединены карточки [323158375, 323158470, 323158652] под imtID 304586629
# ✅ Успешно объединены карточки [323158340, 323158362, 323158478] под imtID 304586598
# ✅ Успешно объединены карточки [323158432, 323158464, 323158483] под imtID 304586687
# ✅ Успешно объединены карточки [323158490, 323158494, 323158505] под imtID 304586857
# ✅ Успешно объединены карточки [323158317, 323158497, 323158747] под imtID 304586576
# ✅ Успешно объединены карточки [323158315, 323158567, 323158763] под imtID 304586573
# ✅ Успешно объединены карточки [323158322, 323158463, 323158643] под imtID 304586580
# ✅ Успешно объединены карточки [323158331, 323158347, 323158598] под imtID 304586589
# ✅ Успешно объединены карточки [323158342, 323158346, 323158727] под imtID 304586599
# ✅ Успешно объединены карточки [323158324, 323158558, 323158732] под imtID 304586583
# ✅ Успешно объединены карточки [323158334, 323158669, 323158728] под imtID 304586592
# ✅ Успешно объединены карточки [323158348, 323158353, 323160318] под imtID 304586605
# ✅ Успешно объединены карточки [323158327, 323158626, 323158641] под imtID 304586585
# ✅ Успешно объединены карточки [323158333, 323158370, 323158743] под imtID 304586591
# ✅ Успешно объединены карточки [323158350, 323158479, 323158682] под imtID 304586608
# ✅ Успешно объединены карточки [323158330, 323158492, 323158515] под imtID 304586588
# ✅ Успешно объединены карточки [323158364, 323158468, 323158636] под imtID 304586619
# ✅ Успешно объединены карточки [323158359, 323158496, 323158665] под imtID 304586615
# ✅ Успешно объединены карточки [323158352, 323158661, 323158688] под imtID 304586611
# ✅ Успешно объединены карточки [323158374, 323158602, 323158677] под imtID 304586628
# ✅ Успешно объединены карточки [323158372, 323158384, 323158475] под imtID 304586626
# ✅ Успешно объединены карточки [323158381, 323158529, 323158660] под imtID 304586635
# ✅ Успешно объединены карточки [323158426, 323158500, 323158629] под imtID 304586681
# ✅ Успешно объединены карточки [323158424, 323158458, 323158616] под imtID 304586679
# ✅ Успешно объединены карточки [323158430, 323158593, 323158599] под imtID 304586685
# ✅ Успешно объединены карточки [323158449, 323158452, 323158768] под imtID 304586706
# ✅ Успешно объединены карточки [323158383, 323158561, 323158754] под imtID 304586637
# ✅ Успешно объединены карточки [323158380, 323158622, 323158730] под imtID 304586634
# ✅ Успешно объединены карточки [323158433, 323158487, 323158751] под imtID 304586688
# ✅ Успешно объединены карточки [323158457, 323158472, 323158473] под imtID 304586826
# ✅ Успешно объединены карточки [323158428, 323158466, 323158594] под imtID 304586684
# ✅ Успешно объединены карточки [323158506, 323158556, 323158764] под imtID 304586872
# ✅ Успешно объединены карточки [323158459, 323158657, 323158711] под imtID 304586828
# ✅ Успешно объединены карточки [323158498, 323158501, 323158524] под imtID 304586864
# ✅ Успешно объединены карточки [323158499, 323158557, 323158672] под imtID 304586865
# ✅ Успешно объединены карточки [323158471, 323158739, 323158769] под imtID 304586840
# ✅ Успешно объединены карточки [323158503, 323158709, 323158725] под imtID 304586869
# ✅ Успешно объединены карточки [323158555, 323158647, 323158715] под imtID 304586889
# ✅ Успешно объединены карточки [323158564, 323158694, 323158717] под imtID 304586899
# ✅ Успешно объединены карточки [323158671, 323158722, 323158757] под imtID 304587003
# ✅ Успешно объединены карточки [323158649, 323158690, 323158718] под imtID 304586978
# ✅ Успешно объединены карточки [323161995, 323161998, 323162013] под imtID 304589717
# ✅ Успешно объединены карточки [323161999, 323162001, 323162015] под imtID 304589721
# ✅ Успешно объединены карточки [323161992, 323162003, 323162011] под imtID 304589714
# ✅ Успешно объединены карточки [323158628, 323158638, 323158721] под imtID 304586960
# ✅ Успешно объединены карточки [323161994, 323161996, 323162004] под imtID 304589716
# ✅ Успешно объединены карточки [323161990, 323161993, 323162016] под imtID 304589711
# ✅ Успешно объединены карточки [323162002, 323162007, 323162020] под imtID 304589726
# ✅ Успешно объединены карточки [323161997, 323162014, 323162021] под imtID 304589719
# ✅ Успешно объединены карточки [323162000, 323162008, 323162017] под imtID 304589724
# ✅ Успешно объединены карточки [323162006, 323162009, 323162019] под imtID 304589730
