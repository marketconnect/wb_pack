# %%
import pandas as pd
import json
import getpass
import requests
import datetime
import os

# %%
WB_TOKEN = os.getenv('WB_TOKEN')
headers = {'Authorization': WB_TOKEN}

# %%
subj_chars_url = 'https://content-api.wildberries.ru/content/v2/object/charcs/3979'
resp = requests.get(subj_chars_url, headers=headers)

# %%
d = json.loads( resp.text)

# %%
d
# Out:
# {'data': [{'charcID': 59611,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Назначение подарка',
#    'required': False,
#    'unitName': '',
#    'maxCount': 3,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 88952,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Вес товара с упаковкой (г)',
#    'required': False,
#    'unitName': 'г',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 89008,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Вес товара без упаковки (г)',
#    'required': False,
#    'unitName': 'г',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 90630,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Высота предмета',
#    'required': False,
#    'unitName': 'см',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 90652,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Глубина предмета',
#    'required': False,
#    'unitName': 'см',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 90673,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Ширина предмета',
#    'required': False,
#    'unitName': 'см',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 162209,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Толщина листа',
#    'required': False,
#    'unitName': 'мм',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 4},
#   {'charcID': 179792,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Количество предметов в упаковке',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': True,
#    'charcType': 1},
#   {'charcID': 353212,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Нагрузка до',
#    'required': False,
#    'unitName': '',
#    'maxCount': 3,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 378533,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Комплектация',
#    'required': False,
#    'unitName': '',
#    'maxCount': 12,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 14177449,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Цвет',
#    'required': False,
#    'unitName': '',
#    'maxCount': 5,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 14177451,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Страна производства',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 14177453,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'SKU',
#    'required': False,
#    'unitName': '',
#    'maxCount': 0,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15000432,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Форма коробки',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15000783,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Объем товара (л)',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001135,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Номер декларации соответствия',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001136,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Номер сертификата соответствия',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001137,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Дата регистрации сертификата/декларации',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001138,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Дата окончания действия сертификата/декларации',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001405,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Ставка НДС',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001650,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'ИКПУ',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15001706,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Код упаковки',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1},
#   {'charcID': 15002205,
#    'subjectName': 'Коробки картонные',
#    'subjectID': 3979,
#    'name': 'Марка картона',
#    'required': False,
#    'unitName': '',
#    'maxCount': 1,
#    'popular': False,
#    'charcType': 1}],
#  'error': False,
#  'errorText': '',
#  'additionalErrors': None}

# %%
names = [n['name'] + "->" + str(n['required']) for n in d['data']]

# %%
import os
import re
import sqlite3

def gather_products_from_folder_and_db(db_path, images_folder):
    """
    1. Берёт все файлы формата 'product_id-qty.jpg' из заданной папки.
    2. Извлекает из имени файла product_id и количество (qty).
    3. Достаёт данные из таблицы products по product_id.
    4. Формирует структуру для Wildberries (subjectID, variants и т.д.).
    5. Возвращает список объектов, готовый для отправки в API.
    """
    
    # Регулярное выражение для поиска product_id-qty.jpg
    pattern = re.compile(r'^(\d+)-(\d+)\.jpg$', re.IGNORECASE)
    
    # Соединяемся с БД
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Список, куда будем складывать товары
    products_list = []
    
    # Обходим все файлы в папке
    for filename in os.listdir(images_folder):
        match = pattern.match(filename)
        if not match:
            continue
        
        product_id, quantity_str = match.groups()
        
        # Пытаемся получить данные о товаре по product_id
        cursor.execute("SELECT * FROM products WHERE product_id = ?", (product_id,))
        row = cursor.fetchone()
        
        # Если в БД нет записи — пропускаем
        if not row:
            continue
        
        # Раскладываем строки по названным полям (см. структуру CREATE TABLE products)
        (
            row_id,
            db_product_id,
            name,
            price_str,
            description,
            material,
            length_mm,
            width_mm,
            height_mm,
            volume_l,
            cardboard_brand,
            cardboard_type,
            color,
            has_handles,
            box_shape,
            weight_g,
            transport_volume_m3,
            trade_mark,
            manufacturer_country
        ) = row
        
        # Конвертируем некоторые значения в см (из мм)
        # Высота предмета
        height_cm = None
        if height_mm:
            try:
                height_cm = round(float(height_mm) / 10, 2)  # 'см', округлим до 2 знаков
            except:
                pass
        
        # Глубина (пусть будет length_mm)
        depth_cm = None
        if length_mm:
            try:
                depth_cm = round(float(length_mm) / 10, 2)
            except:
                pass
        
        # Ширина (width_mm)
        width_cm = None
        if width_mm:
            try:
                width_cm = round(float(width_mm) / 10, 2)
            except:
                pass
        
        # Цена (из строки уберём буквы, оставим только число)
        # Например, "30.35 p" -> 30.35 -> 30 (округлённая) или в копейках как целое число
        # price_val = 0
        # if price_str:
        #     try:
        #         # Удалим всё кроме цифр и точки
        #         price_num = re.sub(r'[^0-9.,]', '', price_str).replace(',', '.')
        #         price_val = int(float(price_num))
        #     except:
        #         pass
        
        # Характеристики. Собираем массив characteristics в зависимости от непустых полей.
        characteristics = []
        
        # Количество предметов в упаковке (charcID=179792) -> из quantity_str
        if quantity_str:
            characteristics.append({"id": 179792, "value": [quantity_str]})
        
        # Вес товара с упаковкой (г) (charcID=88952) -> из weight_g
        if weight_g:
            characteristics.append({"id": 88952, "value": int(float(weight_g)*int(quantity_str))})
        
        # Цвет (charcID=14177449)
        if color:
            characteristics.append({"id": 14177449, "value": ["крафт"]})
        
        # Страна производства (charcID=14177451)
        if manufacturer_country:
            characteristics.append({"id": 14177451, "value": [manufacturer_country]})
        
        # Марка картона (charcID=15002205)
        if cardboard_brand:
            characteristics.append({"id": 15002205, "value": [cardboard_brand]})
        
        # Форма коробки (charcID=15000432)
        if box_shape:
            characteristics.append({"id": 15000432, "value": [box_shape]})
        
        # Объем товара (л) (charcID=15000783)
        # if volume_l:
        #     try:
        #         volume_val = float(volume_l)
        #         characteristics.append({"id": 15000783, "value": volume_val})
        #     except:
        #         pass
        
        # Высота предмета (charcID=90630)
        if height_cm is not None:
            characteristics.append({"id": 90630, "value": height_cm})
        
        # Глубина предмета (charcID=90652)
        if depth_cm is not None:
            characteristics.append({"id": 90652, "value": depth_cm})
        
        # Ширина предмета (charcID=90673)
        if width_cm is not None:
            characteristics.append({"id": 90673, "value": width_cm})
        
        # Формируем title: к наименованию добавляем, например, "(10 шт.)"
        final_title = f"{name} {quantity_str} шт."
        
        # vendorCode: box_{product_id}_{количество}
        vendor_code = f"box_{product_id}_{quantity_str}"
        
        # dimensions — размеры упаковки для Wildberries (указываем в сантиметрах)
        # Если нужно указать точные габариты, можно взять из length_cm, width_cm, height_cm
        # Здесь, как пример, возьмём их, округляя до int
        dimensions = {
            # "length": int(depth_cm) if depth_cm else 0,
            "length": int(((height_cm*2) + (depth_cm * 2))*1.1) if height_cm else 0,
            "width": int(((width_cm*2) +  (depth_cm * 2))*1.1) if width_cm else 0,
            "height": int(int(quantity_str) * 0.3) if height_cm else 0
        }
        
        # Собираем "variants". В sizes можно указать одну "размерную" сущность
        # c ценой price_val (или более сложную логику, если нужно).
        variant = {
            "vendorCode": vendor_code,
            "title": final_title,
            "description": description,
            # "brand": trade_mark if trade_mark else "NoName",
            "dimensions": dimensions,
            "characteristics": characteristics,
            # "sizes": [
            #     {
            #         "techSize": "OneSize",
            #         "wbSize": "1",
            #         # "price": price_val,
            #         # "skus": [
            #         #     f"{product_id}-{quantity_str}"
            #         # ]
            #     }
            # ]
        }
        
        # subjectID 3979 — "Коробки картонные"
        product_object = {
            "subjectID": 3979,
            "variants": [variant]
        }
        
        # Добавляем в итоговый список
        products_list.append(product_object)
    
    # Закрываем соединение
    conn.close()
    
    return products_list

# %%
db_file = "products.db"  # путь к вашей базе данных
folder_path = "images_900_1200"

result = gather_products_from_folder_and_db(db_file, folder_path)
for item in result:
    print(item)
# Здесь item — уже готовая структура для Wildberries API.
# Дальше можно вызывать свой метод create_product_cards(result), как в предыдущем примере.
# Out:
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604580_50', 'title': 'Коробка №204/1 (премиум), беленая, 135*85*55 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №204/1 (премиум) белёный, длиной 135 мм, шириной 85 мм\xa0и высотой 55 мм. Изготовлен из микрогофрокартона Е-22. Полезный объём — 0.6 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nкомпактные размеры коробки;\nнизкая стоимость.\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 41, 'width': 48, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 1300}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Е-22']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.5}, {'id': 90652, 'value': 13.5}, {'id': 90673, 'value': 8.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9601645_30', 'title': 'Картонная коробка для бутылки №95, 100*100*310 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКоробка для бутылки №95, бурая, длиной 100 мм, шириной 100 мм и высотой 310 мм. Изготовлена из трёхслойного картона Т-24 В. Полезный объём — 3.1 л.\nКоробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nОбласть применения:\nПредназначена для надёжной упаковки и транспортировки бутылки. Можно использовать для хранения и перевозки любых других предметов, подходящих по габаритам — тонких ваз, бокалов, украшений и сувениров. Если между стенками коробки и предметом остаётся свободное место, рекомендуем заполнить его наполнителем, чтобы содержимое не повредилось во время транспортировки. Из коробки для бутылки можно сделать яркую упаковку для подарка, завернув её в бумагу тишью и добавив в качестве декора бант из атласной ленты.\nПреимущества:\nплотно закрывается;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nнебольшой вес (актуально при необходимости пересыла почтой);\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 90, 'width': 44, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 2400}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-24 В']}, {'id': 15000432, 'value': ['Высокая']}, {'id': 90630, 'value': 31.0}, {'id': 90652, 'value': 10.0}, {'id': 90673, 'value': 10.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602796_50', 'title': 'Короб КС-403 МГФ, белый, 110*110*35 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-403 МГФ, серии КС-400, белый, длиной 110 мм, шириной 110 мм и высотой 35 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.4 л.\nОбласть применения:\nПредназначен для хранения и транспортировки маленьких, но важных предметов — карт, визиток, ключей, крепёжных изделий. Может быть использован в качестве подарочной упаковки. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из микрогофрокартона Т-23;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 31, 'width': 48, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 1000}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 3.5}, {'id': 90652, 'value': 11.0}, {'id': 90673, 'value': 11.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222018_30', 'title': 'Короб К-154, 180*180*80 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб К-154 бурого цвета, длиной 180 мм, шириной 180 мм и высотой 80 мм. Изготовлен из трехслойного картона марки Т-23 В. Полезный объём — 2.59 л.\nОбласть применения:\nПредназначен для упаковки и транспортировки небольших грузов. Изготовлен из целлюлозы, поэтому отличается износостойкостью и пригоден для последующего использования. В этом коробе можно перевозить канцтовары (клей, ножницы, ручки, степлер), посуду, хозяйственные товары, предметы гигиены, сувениры и съедобные предметы в обёртке (фрукты, сладости). Если вы приобретаете больше одной коробки, рекомендуем маркировать их с помощью стикеров или маркеров, чтобы не забыть, какие товары находятся в каждой из них.\nПреимущества:\nЛегко упаковывается с помощью скотча.\nВозможность маркировки картонной поверхности.\nЗащищает вещи от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 57, 'width': 79, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 3270}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Квадратная']}, {'id': 90630, 'value': 8.0}, {'id': 90652, 'value': 18.0}, {'id': 90673, 'value': 18.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602822_10', 'title': 'Короб КС-428 МГФ, белый, 210*75*40 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-428 МГФ, серии КС-400, белый, длиной 210 мм, шириной 75 мм и высотой 40 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.6 л.\nОбласть применения:\nПродолговатый плоский короб подойдёт для упаковки и транспортировки ювелирных украшений и бижутерии, сладостей или канцелярских товаров — линеек, карандашей и ручек, канцелярских ножей и ножниц. Если вы планируете использовать эту коробку в качестве подарочной упаковки, рекомендуем добавить в коробку\xa0бумажный наполнитель, чтобы предметы не повредились во время перевозки. Украсить внешний вид коробки можно с помощью бумаги тишью, обёрточной бумаги и других ярких товаров для оформления и декора.\xa0Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 55, 'width': 62, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 310}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 4.0}, {'id': 90652, 'value': 21.0}, {'id': 90673, 'value': 7.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602795_30', 'title': 'Короб КС-401 МГФ, белый, 135*130*120 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-401 МГФ, серии КС-400, белый, длиной 135 мм, шириной 130 мм и высотой 120 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 2.1 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов — украшений и сувениров, товаров хэнд-мэйд, мыла ручной работы, косметики или лекарств. За счёт своей компактности может быть использован в качестве подарочной упаковки. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из микрогофрокартона Т-23;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 56, 'width': 58, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 2400}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Квадратная']}, {'id': 90630, 'value': 12.0}, {'id': 90652, 'value': 13.5}, {'id': 90673, 'value': 13.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602808_30', 'title': 'Короб КС-415 МГФ, белый, 170*75*35 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-415 МГФ, серии КС-400, белый, длиной 170 мм, шириной 75 мм и высотой 35 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.4 л.\nОбласть применения:\nЭтот миниатюрный плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. Кольцо для любимой девушки, изящный браслет для подруги, стразы и бусины, мелкие крепёжные изделия, школьные валентинки и записки или коллекция редких монет — можно придумать сотни вариантов для его использования. Добавьте в коробку подарочный наполнитель, чтобы сюрприз попал к адресату целым и невредимым или удачно перенёс долгий переезд. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 45, 'width': 53, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 600}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 3.5}, {'id': 90652, 'value': 17.0}, {'id': 90673, 'value': 7.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604677_30', 'title': 'Подарочная коробка «С Новым годом!», чёрная, 170*90*50 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nПодарочная коробка «С Новым годом!» чёрная, с поздравительной надписью, длиной 170 мм, шириной 90 мм и высотой 50 мм. Изготовлена из микрогофрокартона Е-22. Полезный объём — 0.76 л.\nОбласть применения:\nПорадуйте своих близких не только приятным сувениром, но и его упаковкой! Эта коробка\xa0— идеальный вариант для тех, кто не умеет красиво упаковывать подарки своими руками или просто не успевает это сделать.\nВам не придётся заучивать поздравительную речь, ведь на лицевой и внутренней сторонах коробки написаны новогодние поздравления, поэтому она всё скажет за вас.\nСюда поместятся коробочка с браслетом или колье, фотографии с открыткой или миниатюрный флакон духов.\nЕсли вы не считаете чёрный цвет подходящим к новогодней кутерьме, то можете добавить красок этой коробке при помощи атласных лент или бумаги тишью.\nПреимущества:\nплотно прилегающая крышка;\nнадпись на коробке с поздравлением;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nнизкая стоимость;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 48, 'width': 57, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 780}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Е-22']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.0}, {'id': 90652, 'value': 17.0}, {'id': 90673, 'value': 9.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9603832_30', 'title': 'Почтовый короб «Бизнес», тип «Ж», 170*120*100 мм, T21, 100% вторсырье 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nПочтовый короб «Бизнес» тип «Ж» бурого цвета, длиной 170 мм, шириной 120 мм и высотой 100 мм. Изготовлен из трёхслойного гофрокартона Т-21. Полезный объём — 2 л.\nОбласть применения:\nПочтовый короб «Бизнес» типа «Ж» - современная, недорогая упаковка для отправки посылок. Коробка имеет достаточно легкий вес, чтобы не утяжелять посылку. Подходит для упаковки и пересылки товаров, вещей и различных мелочей. Прочностных характеристик данного короба вполне хватит для разовой пересылки, зато экономия в стоимости упаковки «налицо». Почтовый короб «Бизнес» поставляется в виде обычного листа. Это позволяет хранить запас коробок в максимально компактном виде. Рекомендуем использовать дополнительную упаковку для заполнения пустот и с целью сохранности вложения — крафт бумагу, воздушно-пузырьковую плёнку, пенопластовый наполнитель.\nПреимущества:\nизготовлен из трёхслойного гофрокартона Т-21;\nне требуется дополнительная упаковка скотчем;\nоснащён плотно прилегающей крышкой;\nклапаны фиксируются без применения клея;\nнизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 59, 'width': 63, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 1860}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-21']}, {'id': 15000432, 'value': ['Прямоугольная']}, {'id': 90630, 'value': 10.0}, {'id': 90652, 'value': 17.0}, {'id': 90673, 'value': 12.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222212_50', 'title': 'Короб КС-55, 380*175*55 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-55 бурый, длиной 380 мм, шириной 175 мм и высотой 55 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 3.66 л.\nОбласть применения:\nПродолговатый короб удобен для хранения и транспортировки узких и длинных вещей. Сюда поместятся канцтовары (ручки, линейки, карандаши), украшения, сувениры, бытовые мелочи и сладости. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nплотно прилегающая крышка;\nупаковка без помощи клея и скотча;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 95, 'width': 122, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 4950}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-24 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.5}, {'id': 90652, 'value': 38.0}, {'id': 90673, 'value': 17.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222018_10', 'title': 'Короб К-154, 180*180*80 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб К-154 бурого цвета, длиной 180 мм, шириной 180 мм и высотой 80 мм. Изготовлен из трехслойного картона марки Т-23 В. Полезный объём — 2.59 л.\nОбласть применения:\nПредназначен для упаковки и транспортировки небольших грузов. Изготовлен из целлюлозы, поэтому отличается износостойкостью и пригоден для последующего использования. В этом коробе можно перевозить канцтовары (клей, ножницы, ручки, степлер), посуду, хозяйственные товары, предметы гигиены, сувениры и съедобные предметы в обёртке (фрукты, сладости). Если вы приобретаете больше одной коробки, рекомендуем маркировать их с помощью стикеров или маркеров, чтобы не забыть, какие товары находятся в каждой из них.\nПреимущества:\nЛегко упаковывается с помощью скотча.\nВозможность маркировки картонной поверхности.\nЗащищает вещи от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 57, 'width': 79, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 1090}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Квадратная']}, {'id': 90630, 'value': 8.0}, {'id': 90652, 'value': 18.0}, {'id': 90673, 'value': 18.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9601614_50', 'title': 'Книжный лоток №6, 250*175*50 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКнижный лоток №6, бурый, длиной 250 мм, шириной 175 мм и высотой 50 мм. Изготовлен из трёхслойного картона Т-23 В. Полезный объём — 2.2 л.\nКоробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nОбласть применения:\nПредназначен для надёжной упаковки и транспортировки книг. Можно использовать для хранения и перевозки любых других предметов, подходящих по габаритам — обложек для паспорта, блокнотов, украшений и сувениров. Из книжного лотка можно сделать надёжную и яркую упаковку для подарка, завернув его в бумагу тишью и добавив в качестве декора бант из атласной ленты.\nПреимущества:\nплотно закрывается;\nразные размеры книжных лотков для разных книг;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nнебольшой вес (актуально при необходимости пересыла почтой);\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 66, 'width': 93, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 3550}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.0}, {'id': 90652, 'value': 25.0}, {'id': 90673, 'value': 17.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222122_10', 'title': 'Короб КС-27, 130*80*55 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-27 бурый, длиной 130 мм, шириной 80 мм и высотой 55 мм. Изготовлен из трёхслойного картона Т-23 В. Полезный объём — 0.57 л.\nОбласть применения:\nКороб с прилегающей крышкой удобен для хранения и транспортировки ценных вещей и мелочей, которые легко потерять. Сюда поместятся украшения и небольшие сувениры, ручки и карандаши, косметика, ключи, зарядные устройства, батарейки, медикаменты или щётки с зубной пастой. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 40, 'width': 46, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 410}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.5}, {'id': 90652, 'value': 13.0}, {'id': 90673, 'value': 8.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602814_30', 'title': 'Короб КС-420 МГФ, белый, 145*155*55 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-420 МГФ, серии КС-400, белый, длиной 145 мм, шириной 155 мм и высотой 55 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.2 л.\nОбласть применения:\nЭтот небольшой плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. У него есть откидная крышка, которая плотно закрывается, поэтому мелкие предметы не выпадут во время перевозки. Вы можете положить в короб небольшие сувениры и украшения в подарок близкому человеку, набор магнитов с холодильника на время переезда, коллекцию редких монет и многое другое. Чтобы украсить коробку изнутри и не повредить предметы в период транспортировки, положите внутрь цветной\xa0подарочный наполнитель. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 44, 'width': 66, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 1800}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.5}, {'id': 90652, 'value': 14.5}, {'id': 90673, 'value': 15.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602798_10', 'title': 'Короб КС-405 МГФ, белый, 195*135*75 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-405 МГФ, серии КС-400, белый, длиной 195 мм, шириной 135 мм и высотой 75 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.95 л.\nОбласть применения:\nЭтот короб станет отличным вариантом для упаковки подарка. В него поместятся милые сердцу безделушки, сладости, сувениры и даже коробочка с кольцом или браслетом. В качестве украшения коробки можно выбрать одну из ярких атласных лент. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из микрогофрокартона Т-23;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 59, 'width': 72, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 600}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 7.5}, {'id': 90652, 'value': 19.5}, {'id': 90673, 'value': 13.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604317_30', 'title': 'Коробка №200/1 (премиум), беленая, 210*150*90 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №200/1 (премиум) белёный, длиной 210 мм, шириной 150 мм и высотой 90 мм. Изготовлен\xa0из микрогофрокартона Е-22. Полезный объём — 2.83 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 66, 'width': 79, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 2040}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Е-22']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 9.0}, {'id': 90652, 'value': 21.0}, {'id': 90673, 'value': 15.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602803_50', 'title': 'Короб КС-410 МГФ, белый, 130*130*70 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-410 МГФ, серии КС-400, белый, длиной 130 мм, шириной 130 мм и высотой 70 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.15 л.\nОбласть применения:\nЭтот короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. Сюда поместятся сувениры и украшения, косметика и лекарства, пуговицы и бусины, товары хэнд-мэйд или даже сладости. Оберните коробку в одну из ярких атласных лент, чтобы придать ей вид подарочной упаковки. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 44, 'width': 57, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 2100}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 7.0}, {'id': 90652, 'value': 13.0}, {'id': 90673, 'value': 13.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222200_10', 'title': 'Короб КС-21, 200*120*30 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-21 бурый, длиной 200 мм, шириной 120 мм и высотой 30 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 0.72 л.\nОбласть применения:\nЭтот небольшой короб удобен для хранения и транспортировки ценных мелочей, которые легко потерять во время транспортировки. Сюда поместятся канцтовары (ручки, линейки, карандаши), украшения, сувениры, бытовые мелочи и сладости. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nплотно прилегающая крышка;\nупаковка без помощи клея и скотча;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 50, 'width': 70, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 460}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-24 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 3.0}, {'id': 90652, 'value': 20.0}, {'id': 90673, 'value': 12.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604102_50', 'title': 'Короб КС-621 МГК, 150*150*55 мм 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-621 МГК, серии КС-600, бурый, длиной 150 мм, шириной 150 мм и высотой 55 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 1.2 л.\nОбласть применения:\nЭтот небольшой плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. У него есть откидная крышка, которая плотно закрывается, поэтому мелкие предметы не выпадут во время перевозки. Вы можете положить в короб небольшие сувениры и украшения в подарок близкому человеку, набор магнитов с холодильника на время переезда, коллекцию редких монет и многое другое. Чтобы украсить коробку изнутри и не повредить предметы в период транспортировки, положите внутрь цветной\xa0подарочный наполнитель. Снаружи коробку можно дополнить бумагой тишью и бантом из атласной ленты. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 45, 'width': 66, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 1950}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 Е']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.5}, {'id': 90652, 'value': 15.0}, {'id': 90673, 'value': 15.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9600301_30', 'title': 'Короб №23, 200*200*200 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКартонный короб №23 для переезда, длиной 200 мм, шириной 200 мм и высотой 200 мм. Изготовлен из трехслойного картона марки Т-23. Полезный объём — 8 л.\nОбласть применения:\nКороб №23 пригодится при офисных, квартирных, дачных переездах. Применяется для упаковки различных мелочей —\xa0лекарств, женской косметики, сыпучих грузов, упакованных в пленку.\xa0При этом можно приклеить скотчем надписи на каждую коробочку, и все ваши важные мелочи не потеряются, а будут под рукой.\nПреимущества:\nИзготовлен из трёхслойного картона марки Т-23 В.\nЛегко упаковывается с помощью скотча.\nЗащищает вещи от механических повреждений, влаги и солнечных лучей.\nПодходит для многоразового использования.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 88, 'width': 88, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 5250}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Квадратная']}, {'id': 90630, 'value': 20.0}, {'id': 90652, 'value': 20.0}, {'id': 90673, 'value': 20.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222224_30', 'title': 'Короб КС-77, 320*240*50 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-77 бурый, длиной 320 мм, шириной 240 мм и высотой 50 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 3.84 л.\nОбласть применения:\nЭтот небольшой короб удобен для хранения и транспортировки ценных мелочей, которые легко потерять во время транспортировки. Сюда поместятся канцтовары (ручки, линейки, карандаши), украшения, сувениры, бытовые мелочи и сладости. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nплотно прилегающая крышка;\nупаковка без помощи клея и скотча;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 81, 'width': 123, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 3120}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-24 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.0}, {'id': 90652, 'value': 32.0}, {'id': 90673, 'value': 24.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602795_10', 'title': 'Короб КС-401 МГФ, белый, 135*130*120 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-401 МГФ, серии КС-400, белый, длиной 135 мм, шириной 130 мм и высотой 120 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 2.1 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов — украшений и сувениров, товаров хэнд-мэйд, мыла ручной работы, косметики или лекарств. За счёт своей компактности может быть использован в качестве подарочной упаковки. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nкоробка изготовлена из микрогофрокартона Т-23;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 56, 'width': 58, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 800}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Квадратная']}, {'id': 90630, 'value': 12.0}, {'id': 90652, 'value': 13.5}, {'id': 90673, 'value': 13.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9603052_10', 'title': 'Коробка крафт кондитерская, беленая, 215*150*60 мм 10 шт.', 'description': 'Коробка крафт кондитерская, беленая, длиной 215 мм, шириной 150 мм и высотой 60 мм. Изготовлена из крафт картона. Полезный объём — 1.94 л.\nОбласть применения:\nПредназначена для упаковки и транспортировки кондитерских изделий — пирожных, чизкейков, печенья, кексов, вафель. Изготовлена из картона светлого оттенка, который придаёт коробке аккуратный вид. Закрывается при помощи крышки — удлиннённой боковой стенки.\nПреимущества:\nЗакрывается крышкой-стенкой\nВозможность маркировки картонной поверхности.\nЗащищает продукты от влаги и солнечных лучей.\nНизкая стоимость.\nИзделия из крафт картона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ℃ и относительной влажности (65∓15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения изделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 60, 'width': 80, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 350}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 90630, 'value': 6.0}, {'id': 90652, 'value': 21.5}, {'id': 90673, 'value': 15.0}]}]}
# ...
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_222192_10', 'title': 'Короб КС-4, 120*120*60 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-4 бурый, длиной 120 мм, шириной 120 мм и высотой 60 мм. Изготовлен из трёхслойного картона Т-24 В. Полезный объём — 0.86 л.\nОбласть применения:\nКороб с прилегающей крышкой удобен для хранения и транспортировки ценных вещей и мелочей, которые легко потерять. Сюда поместятся украшения и небольшие сувениры, косметика, ключи, зарядные устройства, батарейки или медикаменты. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 39, 'width': 52, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 220}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-24 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 6.0}, {'id': 90652, 'value': 12.0}, {'id': 90673, 'value': 12.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604543_50', 'title': 'Короб КС-221, 130*90*40 мм, Т-23 Е 50 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-221 бурого цвета, длиной 130 мм, шириной 90 мм и высотой 40 мм. Изготовлен из трёхслойного гофрокартона Т-23 Е. Полезный объём — 0.5 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nкороб изготовлен из трёхслойного гофрокартона Т-23 Е;\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nкомпактный размер коробки;\nэкологичность.\nнизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 37, 'width': 48, 'height': 15}, 'characteristics': [{'id': 179792, 'value': ['50']}, {'id': 88952, 'value': 1150}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 Е']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 4.0}, {'id': 90652, 'value': 13.0}, {'id': 90673, 'value': 9.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9603832_10', 'title': 'Почтовый короб «Бизнес», тип «Ж», 170*120*100 мм, T21, 100% вторсырье 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nПочтовый короб «Бизнес» тип «Ж» бурого цвета, длиной 170 мм, шириной 120 мм и высотой 100 мм. Изготовлен из трёхслойного гофрокартона Т-21. Полезный объём — 2 л.\nОбласть применения:\nПочтовый короб «Бизнес» типа «Ж» - современная, недорогая упаковка для отправки посылок. Коробка имеет достаточно легкий вес, чтобы не утяжелять посылку. Подходит для упаковки и пересылки товаров, вещей и различных мелочей. Прочностных характеристик данного короба вполне хватит для разовой пересылки, зато экономия в стоимости упаковки «налицо». Почтовый короб «Бизнес» поставляется в виде обычного листа. Это позволяет хранить запас коробок в максимально компактном виде. Рекомендуем использовать дополнительную упаковку для заполнения пустот и с целью сохранности вложения — крафт бумагу, воздушно-пузырьковую плёнку, пенопластовый наполнитель.\nПреимущества:\nизготовлен из трёхслойного гофрокартона Т-21;\nне требуется дополнительная упаковка скотчем;\nоснащён плотно прилегающей крышкой;\nклапаны фиксируются без применения клея;\nнизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 59, 'width': 63, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 620}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-21']}, {'id': 15000432, 'value': ['Прямоугольная']}, {'id': 90630, 'value': 10.0}, {'id': 90652, 'value': 17.0}, {'id': 90673, 'value': 12.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604317_10', 'title': 'Коробка №200/1 (премиум), беленая, 210*150*90 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб №200/1 (премиум) белёный, длиной 210 мм, шириной 150 мм и высотой 90 мм. Изготовлен\xa0из микрогофрокартона Е-22. Полезный объём — 2.83 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 66, 'width': 79, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 680}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Е-22']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 9.0}, {'id': 90652, 'value': 21.0}, {'id': 90673, 'value': 15.0}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9601614_30', 'title': 'Книжный лоток №6, 250*175*50 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКнижный лоток №6, бурый, длиной 250 мм, шириной 175 мм и высотой 50 мм. Изготовлен из трёхслойного картона Т-23 В. Полезный объём — 2.2 л.\nКоробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nОбласть применения:\nПредназначен для надёжной упаковки и транспортировки книг. Можно использовать для хранения и перевозки любых других предметов, подходящих по габаритам — обложек для паспорта, блокнотов, украшений и сувениров. Из книжного лотка можно сделать надёжную и яркую упаковку для подарка, завернув его в бумагу тишью и добавив в качестве декора бант из атласной ленты.\nПреимущества:\nплотно закрывается;\nразные размеры книжных лотков для разных книг;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nнебольшой вес (актуально при необходимости пересыла почтой);\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 66, 'width': 93, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 2130}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23 В']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.0}, {'id': 90652, 'value': 25.0}, {'id': 90673, 'value': 17.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9602813_10', 'title': 'Короб КС-419 МГФ, белый, 140*145*35 мм 10 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nКороб КС-419 МГФ, серии КС-400, белый, длиной 140 мм, шириной 145 мм и высотой 35 мм. Изготовлен из микрогофрокартона Т-23. Полезный объём — 0.7 л.\nОбласть применения:\nЭтот небольшой плоский короб станет отличным вариантом для хранения и транспортировки ценных мелочей или упаковки подарков. У него есть откидная крышка, которая плотно закрывается, поэтому мелкие предметы не выпадут во время перевозки. Туда поместятся мелкие крепёжные изделия, украшения, фурнитура для рукоделия (бусины, замочки, зажимы) и многое другое. Чтобы придать коробке праздничный вид, перетяните её яркой атласной лентой и украсьте пышным бантом. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча.\nПреимущества:\nвозможность маркировки картонной поверхности;\nне требуется дополнительная упаковка скотчем;\nплотно прилегающая крышка;\nкомпактный размер коробки;\nэкологичность.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.\nЭта коробка изготовлена с применением материалов, получивших вторую жизнь. Мы заботимся о природе и здоровье будущих поколений, поэтому используем в производстве переработанные материалы, полученные из вторичного сырья. Ежемесячно мы пускаем в производство 25-30 тонн бумажного вторсырья. Наша цель — сократить вредные выбросы в атмосферу и постоянно растущие горы мусора. За безотходным производством будущее!', 'dimensions': {'length': 38, 'width': 62, 'height': 3}, 'characteristics': [{'id': 179792, 'value': ['10']}, {'id': 88952, 'value': 400}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Т-23']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 3.5}, {'id': 90652, 'value': 14.0}, {'id': 90673, 'value': 14.5}]}]}
# {'subjectID': 3979, 'variants': [{'vendorCode': 'box_9604318_30', 'title': 'Коробка №201 (премиум), 170*90*50 мм 30 шт.', 'description': 'Размеры коробок (Длина х Ширина х Высота) указаны внутренние. Коробки продаются в разобранном виде.\nДействуют особые условия при заказе от 20000 шт.:\nНеобходима предоплата 100%.\nПри оформлении доставки заказ на части не разделяется.\nПри самовывозе необходимо забрать заказ в течение 2-х дней (далее резерв автоматически снимается, и компания не гарантирует наличие необходимого количества товара).\nКороб №201 (премиум) бурого цвета, длиной 170 мм, шириной 90 мм и высотой 50 мм. Изготовлен\xa0из микрогофрокартона Е-22. Полезный объём — 0.76 л.\nОбласть применения:\nПредназначен для хранения и транспортировки небольших предметов, подходящих по габаритам — украшений и сувениров, лекарств, крепёжных изделий, бусин и пуговиц. Коробка приедет к вам в разобранном виде, чтобы не повредиться в процессе доставки. Легко собирается в единое целое без клея и скотча. Снабжена откидной крышкой.\nПреимущества:\nплотно прилегающая крышка;\nвозможность маркировки картонной поверхности;\nкомпактный размер коробки;\nне требуется дополнительная упаковка скотчем;\nэкологичность.\nнизкая стоимость.\nИзделия из гофрокартона стоит хранить в сухом и чистом помещении при температуре от 0 до 30 ° и относительной влажности (65±15 %) на расстоянии не менее 1 метра от нагревательных приборов. Рекомендованный срок хранения гофроизделий не более 6 месяцев со дня производства.', 'dimensions': {'length': 48, 'width': 57, 'height': 9}, 'characteristics': [{'id': 179792, 'value': ['30']}, {'id': 88952, 'value': 780}, {'id': 14177449, 'value': ['крафт']}, {'id': 14177451, 'value': ['Россия']}, {'id': 15002205, 'value': ['Е-22']}, {'id': 15000432, 'value': ['Плоская']}, {'id': 90630, 'value': 5.0}, {'id': 90652, 'value': 17.0}, {'id': 90673, 'value': 9.0}]}]}

# %%
API_URL = "https://content-api.wildberries.ru/content/v2/cards/upload"



def create_product_cards(products):
  
    try:
        response = requests.post(API_URL, json=products, headers=headers)
        response_data = response.json()
        
        if response.status_code == 200 and not response_data.get("error", True):
            print("Карточки товаров успешно созданы.")
        else:
            print(f"Ошибка: {response_data.get('errorText', 'Неизвестная ошибка')}")
            print("Дополнительные ошибки:", response_data.get("additionalErrors", {}))
        
        return response_data
    except requests.RequestException as e:
        print(f"Ошибка при выполнении запроса: {e}")
        return None

# %%
resp = create_product_cards(result[180:])
# Out:
# Карточки товаров успешно созданы.
